# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
! mongoimport --type json -d uk_food -c establishments --drop --jsonArray ./Resources/establishments.json
# Out:
# 2024-06-24T12:15:42.785-0500	connected to: mongodb://localhost/
# 2024-06-24T12:15:42.786-0500	dropping: uk_food.establishments
# 2024-06-24T12:15:43.833-0500	39779 document(s) imported successfully. 0 document(s) failed to import.

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'epa', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
print(db.establishments.find_one())
# Out:
# {'_id': ObjectId('6679a9be8c9e2a3624d0ed42'), 'FHRSID': 1043695, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000073616', 'BusinessName': 'The Pavilion', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'East Cliff Pavilion', 'AddressLine2': 'Wear Bay Road', 'AddressLine3': 'Folkestone', 'AddressLine4': 'Kent', 'PostCode': 'CT19 6BL', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-04-04T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.195625', 'latitude': '51.083812'}, 'RightToReply': '', 'Distance': 4591.765489457773, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0
# ...

# %%
# review a document in the establishments collection

result = db.establishments.find_one()
# result = establishments.find_one()
pprint( result )
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6679a9be8c9e2a3624d0ed42'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
# ...

# %%
# print(db.establishments.find({"BusinessName":"Boat House & Langdon"}))

# query = {"BusinessName":"Boat House & Langdon"}
# #results = establishments.find(query).sort(sort).limit(limit)
# results = establishments.find(query)
# results_list = list(results)
# pprint(results_list)


query = {"BusinessName":"Boat House & Langdon"}
#results = establishments.find(query).sort(sort).limit(limit)
results = establishments.find(query)
pprint( list(results) )
# Out:
# [{'AddressLine1': 'St Margarets Hotel And Country Club',
#   'AddressLine2': 'Reach Road',
#   'AddressLine3': 'St Margarets At Cliffe',
#   'AddressLine4': 'Kent',
#   'BusinessName': 'Boat House & Langdon',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4588.067654106012,
#   'FHRSID': 254239,
#   'LocalAuthorityBusinessID': 'PI/000068711',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CT15 6AG',
#   'RatingDate': '2021-07-01T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6679a9be8c9e2a3624d0ea63'),
#   'geocode': {'latitude': '51.150372', 'longitude': '1.366199'},
# ...

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
# # Drop a specific collection
# db['establishments'].drop()
# print("Collection 'establishments' dropped successfully.")
# Out:
# Collection 'establishments' dropped successfully.

# %%
# # Drop the entire database
# mongo.drop_database('uk_food')
# print("Database 'uk_food' dropped successfully.")
# Out:
# Database 'uk_food' dropped successfully.

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
print(new_restaurant)
# Out:
# {'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %%
# Insert the new restaurant into the collection

# db.establishments.insertOne(new_restaurant)
establishments.insert_one(new_restaurant)
# Out:
# InsertOneResult(ObjectId('6679b246283f6c27777c6b0c'), acknowledged=True)

# %%
# Check that the new restaurant was inserted

query = {"BusinessName":"Penang Flavours"}
#results = establishments.find(query).sort(sort).limit(limit)
results = establishments.find(query)
pprint( list(results) )
# Out:
# [{'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   'Distance': 4623.972328074718,
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': True,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6679b246283f6c27777c6b0c'),
#   'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#   'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}]

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields


query = {"BusinessType":"Restaurant/Cafe/Canteen"}
fields = {"BusinessTypeID":1, "BusinessType":1}
#results = establishments.find(query).sort(sort).limit(limit)
results = establishments.find(query,fields)
pprint( list(results) )


# query = {"BusinessType":"Restaurant/Cafe/Canteen"}
# fields = {"BusinessTypeID":1, "BusinessType":1}
# #results = establishments.find(query).sort(sort).limit(limit)
# results = establishments.find_one(query,fields)
# pprint( list(results) )
# Out:
# [{'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6679a9be8c9e2a3624d0ea63')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6679a9be8c9e2a3624d0ea65')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6679a9be8c9e2a3624d0ea66')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6679a9be8c9e2a3624d0ea71')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6679a9be8c9e2a3624d0ea74')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6679a9be8c9e2a3624d0ea79')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6679a9be8c9e2a3624d0ea7a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6679a9be8c9e2a3624d0ea7c')},
# ...

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID

db.establishments.update_one({"BusinessName":"Penang Flavours"}, {'$set': {'BusinessTypeID': 1}})
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated

query = {"BusinessName":"Penang Flavours"}
#results = establishments.find(query).sort(sort).limit(limit)
results = establishments.find(query)
pprint( list(results) )
# Out:
# [{'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'Distance': 4623.972328074718,
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': True,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6679b246283f6c27777c6b0c'),
#   'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#   'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}]

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"


query = {"LocalAuthorityName":"Dover"}
fields = {"BusinessName":1, "LocalAuthorityName":1}
#results = establishments.find(query).sort(sort).limit(limit)
results = establishments.find(query,fields)
# results = establishments.find(query)

print(f"results count = {len(list(results))}")

pprint( list(results) )
# Out:
# results count = 994
# []

# %%
# Delete all documents where LocalAuthorityName is "Dover"


query = {"LocalAuthorityName":"Dover"}
establishments.delete_many(query)
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover


query = {"LocalAuthorityName":"Dover"}
fields = {"BusinessName":1, "LocalAuthorityName":1}

results = establishments.find(query,fields)

print(f"results count = {len(list(results))}")
pprint( list(results) )


# results = establishments.find(query)
# for result in results:
#     print(result)
# Out:
# results count = 0
# []

# %%
# Check that other documents remain with 'find_one'


result = db.establishments.find_one()
# result = establishments.find_one()
pprint( result )
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6679a9be8c9e2a3624d0ed42'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
# ...

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# # Change the data type from String to Decimal for longitude and latitude

# # Change the data type from String to Decimal for longitude
# establishments.update_many({}, [ {'$set':{ "longitude" : {'$toDouble': "$longitude"}}} ])

# %%
# # Change the data type from String to Decimal for longitude and latitude

# # Change the data type from String to Decimal for latitude
# establishments.update_many({}, [ {'$set':{ "latitude" : {'$toDouble': "$latitude"}}} ])

# %%
result = db.establishments.find_one()

if result:
    # type_longitude   = type(result['longitude'])
    # type_longitude   = type(result['geocode.longitude'])
    type_longitude   = type(result.get('geocode', {}).get('longitude'))
    
    # type_latitude    = type(result['latitude'])
    # type_latitude    = type(result['geocode.latitude'])
    type_latitude    = type(result.get('geocode', {}).get('latitude'))
    
    type_RatingValue = type(result['RatingValue'])
    
    print(f"The data type of the element with key 'longitude'   is {type_longitude.__name__}.")
    print(f"The data type of the element with key 'latitude'    is {type_latitude.__name__}.")
    print(f"The data type of the element with key 'RatingValue' is {type_RatingValue.__name__}.")
else:
    print("No document found in the 'establishments' collection.")
# Out:
# The data type of the element with key 'longitude'   is str.
# The data type of the element with key 'latitude'    is str.
# The data type of the element with key 'RatingValue' is int.

# %%
# Change the data type from String to Decimal for longitude and latitude



update_query = [
    {
        '$set': { 
            "geocode.longitude" : {'$toDouble': "$geocode.longitude"},
            "geocode.latitude"  : {'$toDouble': "$geocode.latitude"}
        }
    }
]


establishments.update_many({}, update_query )
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
result = db.establishments.find_one()

if result:
    # type_longitude   = type(result['longitude'])
    # type_longitude   = type(result['geocode.longitude'])
    type_longitude   = type(result.get('geocode', {}).get('longitude'))
    
    # type_latitude    = type(result['latitude'])
    # type_latitude    = type(result['geocode.latitude'])
    type_latitude    = type(result.get('geocode', {}).get('latitude'))
    
    type_RatingValue = type(result['RatingValue'])
    
    print(f"The data type of the element with key 'longitude'   is {type_longitude.__name__}.")
    print(f"The data type of the element with key 'latitude'    is {type_latitude.__name__}.")
    print(f"The data type of the element with key 'RatingValue' is {type_RatingValue.__name__}.")
else:
    print("No document found in the 'establishments' collection.")
# Out:
# The data type of the element with key 'longitude'   is float.
# The data type of the element with key 'latitude'    is float.
# The data type of the element with key 'RatingValue' is int.

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue

establishments.update_many({}, [ {'$set':{ "RatingValue" : {'$toInt': "$RatingValue"}}} ])
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# # Check that the coordinates and rating value are now numbers

# query = {"longitude":{'$ne':None}, "latitude":{'$ne':None}}

# result = db.establishments.find_one(query)
# # result = establishments.find_one()
# pprint( result )

# print("")

# print( type(result) )

# print("")

# for field, value in result.items():
#     # print(f"field:{field},value:{value},type(value){type(value)},type(value).__name__{type(value).__name__}")
#     print(f"field:{field}, type:{type(value)}")
    
#     # data_types[field].add(type(value).__name__)

# %%
# # Check that the coordinates and rating value are now numbers

result = db.establishments.find_one()

if result:
    # type_longitude   = type(result['longitude'])
    # type_longitude   = type(result['geocode.longitude'])
    type_longitude   = type(result.get('geocode', {}).get('longitude'))
    
    # type_latitude    = type(result['latitude'])
    # type_latitude    = type(result['geocode.latitude'])
    type_latitude    = type(result.get('geocode', {}).get('latitude'))
    
    type_RatingValue = type(result['RatingValue'])
    
    print(f"The data type of the element with key 'longitude'   is {type_longitude.__name__}.")
    print(f"The data type of the element with key 'latitude'    is {type_latitude.__name__}.")
    print(f"The data type of the element with key 'RatingValue' is {type_RatingValue.__name__}.")
else:
    print("No document found in the 'establishments' collection.")
# Out:
# The data type of the element with key 'longitude'   is float.
# The data type of the element with key 'latitude'    is float.
# The data type of the element with key 'RatingValue' is int.
